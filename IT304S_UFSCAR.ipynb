# %% [markdown]
# <a href="https://colab.research.google.com/github/AriasgL/IT304S_UFSCAR/blob/main/IT304S_UFSCAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IT304S: Contratação de Energia para Grandes Consumidores.
#
# Prof. Dr. Luiz Carlos Pereira da Silva
#
# UFSCAR Grupo 3 Analise de Consumo

# %% [markdown]
# # Metodologia

# %% [markdown]
# Precisamos explicar a metodologia do analase do projeto.
# CRISP_DM

# %% [markdown]
# # Business Understanding

# %% [markdown]
# Definimos nuestras etapas del proceso.

# %% [markdown]
# # Data Understanding

# %%
# !git clone https://github.com/AriasgL/IT304S_UFSCAR.git
# Out:
# Cloning into 'IT304S_UFSCAR'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
import pandas as pd

# %%
abas_de_excel =  pd.ExcelFile("/content/IT304S_UFSCAR/Universidade.xlsx")
abas_de_excel.sheet_names
# Out:
# ['Apresentação', 'UC1', 'UC2', 'UC3', 'UC4']

# %%
UC1 = abas_de_excel.parse("UC1")
UC1.shape
# Out:
# (78, 30)

# %%
UC2 = abas_de_excel.parse("UC2")
UC2.shape
# Out:
# (67, 31)

# %%
UC1.head()
# Out:
#       DATA   ANO  MÊS  ...  Acrescimo_Bamar  Acrescimo_Bverm1  Acrescimo_Bverm2
# 0   6-2014  2014    6  ...              NaN               NaN               NaN
# 1   7-2014  2014    7  ...              NaN               NaN               NaN
# 2   8-2014  2014    8  ...              NaN               NaN               NaN
# 3   9-2014  2014    9  ...              NaN               NaN               NaN
# 4  10-2014  2014   10  ...              NaN               NaN               NaN
#
# [5 rows x 30 columns]

# %%
UC2.head()
# Out:
#         DATA     ANO  MÊS  ...  Acrescimo_Bverm1  Acrescimo_Bverm2  Outros Lanc.
# 0 2020-06-01  2020.0  6.0  ...               NaN               NaN      -4156.26
# 1 2020-05-01  2020.0  5.0  ...               NaN               NaN      -4015.27
# 2 2020-04-01  2020.0  4.0  ...               NaN               NaN      -3756.96
# 3 2020-03-01  2020.0  3.0  ...               NaN               NaN      -4156.35
# 4 2020-02-01  2020.0  2.0  ...               NaN               NaN      -3699.76
#
# [5 rows x 31 columns]

# %% [markdown]
# # Data Preparation

# %%
import numpy as np

# %%
np.nan + np.nan
# Out:
# nan

# %% [markdown]
# # Dados Faltantes

# %%
import missingno as msno

# %%
msno.bar(UC1, color="RoyalBlue") #para visualizar a integridade do datafram

# %%
msno.bar(UC2, color="RoyalBlue") #para visualizar a integridade do datafram

# %%
msno.matrix(UC1, color = (0.25,0.4,0.8))

# %%
msno.matrix(UC2, color = (0.25,0.4,0.8))

# %% [markdown]
# Matriz de Correlacion.

# %%
msno.heatmap(UC1)

# %%
msno.heatmap(UC2)

# %% [markdown]
# Limpeça de Dados Faltantes

# %%
UC1_df = UC1.drop(set(UC1.columns[UC1.isnull().mean() >0.8]), 1)
UC1_df.shape
# Out:
# (78, 22)

# %%
UC2_df = UC2.drop(set(UC2.columns[UC2.isnull().mean() >0.8]), 1)
UC2_df.shape
# Out:
# (67, 17)

# %% [markdown]
# # Graficos das Variaveis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
f, axs = plt.subplots(5, 4,figsize=(20,20))
for i,col in enumerate(UC1_df.columns[3:]):
  plt.subplot(5, 4, i+1)
  plt.title(col)
  plt.plot(UC1_df.DATA, UC1_df[col])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-0d524d1681e0> in <module>()
#       3   plt.subplot(5, 4, i+1)
#       4   plt.title(col)
# ----> 5   plt.plot(UC1_df.DATA, UC1_df[col])
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     337             self.axes.xaxis.update_units(x)
#     338         if self.axes.yaxis is not None:
# --> 339             self.axes.yaxis.update_units(y)
#     340
#     341         if x.shape[0] != y.shape[0]:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axis.py in update_units(self, data)
#    1514         neednew = self.converter != converter
#    1515         self.converter = converter
# -> 1516         default = self.converter.default_units(data, self)
#    1517         if default is not None and self.units is None:
#    1518             self.set_units(default)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/category.py in default_units(data, axis)
#     105         # the conversion call stack is default_units -> axis_info -> convert
#     106         if axis.units is None:
# --> 107             axis.set_units(UnitData(data))
#     108         else:
#     109             axis.units.update(data)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/category.py in __init__(self, data)
#     173         self._counter = itertools.count()
#     174         if data is not None:
# --> 175             self.update(data)
#     176
#     177     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/category.py in update(self, data)
#     210         for val in OrderedDict.fromkeys(data):
#     211             # OrderedDict just iterates over unique values in data.
# --> 212             cbook._check_isinstance((str, bytes), value=val)
#     213             if convertible:
#     214                 # this will only be called so long as convertible is True.
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in _check_isinstance(_types, **kwargs)
#    2126                     ", ".join(names[:-1]) + " or " + names[-1]
#    2127                     if len(names) > 1 else names[0],
# -> 2128                     type_name(type(v))))
#    2129
#    2130
#
# TypeError: 'value' must be an instance of str or bytes, not a float
